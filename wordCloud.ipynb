# %%
import pandas as pd

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
comment_words = ''
stopwords =  list(STOPWORDS)

# %%
val = "Donald Trump was elected on November 8, 2016, in what was widely seen as a surprise upset victory. He was inaugurated as the 45th President of the United States on January 20, 2017. By the time he left office after losing the 2020 presidential election to former Vice President Joe Biden, Trump’s presidency was largely defined by scandal, investigation, and intense partisan division. Both supporters and critics often used the word “unprecedented” to describe his time in office. A number of factors marked Trump as distinctive even before his presidency began. At 70 years old, he was the oldest person to ever become president, surpassing a record set by Ronald Reagan, who was 69 when he took office in 1981. Trump’s successor, Joseph Biden, re-set the record for oldest president when he was inaugurated four years later at age 78. Trump was also the first president never to have served in either public office or in military leadership before arriving in the White House. Finally, he was the fifth person (and the second in sixteen years) to win a victory in the Electoral College but to lose the popular vote. His Democratic challenger in 2016, Hillary Clinton, won 2.8 million more votes than Trump did, but he prevailed in the Electoral College, 304 to 227. Trump was also the first US president to be impeached twice. In December 2019, the Democratically controlled House of Representatives impeached President Trump on the charge of abuse of power and obstruction of Congress because of his efforts to persuade a foreign leader, President Volodymyr Zelensky of Ukraine, to interfere with the upcoming US presidential election. He stood trial in the Senate and was acquitted in February 2020. The House of Representatives impeached President Trump again in January 2021. In a stark break from all past precedent, Trump refused to concede the 2020 presidential election or acknowledge the legitimacy of Biden’s victory, in which Biden won approximately 7 million more votes and the Electoral College vote by 306 to 232. Trump led a protracted effort to undermine the certification of the votes, leading Trump supporters to violently assault the US Capitol on January 6, 2021. That event led to a second impeachment. He stood trial in the Senate and was acquitted again several weeks after his term expired. Donald John Trump was born in the borough of Queens in New York City on June 14, 1946, and remained a New Yorker throughout most of his life. In the waning months of his presidency in the fall of 2020, he formally changed his residency to Florida. He was the fourth of five children born to Mary Anne MacLeod Trump and her husband Fred, a residential real estate developer. As a young adult, Donald Trump took over his father’s real estate business and expanded it into a range of other fields, from hotels and casinos, golf courses, beauty pageants, and branded products around the world. In the 1970s and 1980s, he cultivated an international reputation, both for his branded venues and products as well as for himself personally, as the embodiment of the high life. Through a series of how-to books and, in the 2000s, as the star of a realty television show, The Apprentice, Trump portrayed himself as a fabulously wealthy and talented businessperson. Many of his traditional businesses, including his casinos, suffered financially, and he went through a series of bankruptcies. Yet his ability to craft an association between the brand-name “Trump” and business success remained strong. Donald Trump was also the first US president to have been divorced twice. (Ronald Reagan was the first to have been divorced at all.) He had five children with three wives. The oldest three—Donald, Jr., Ivanka, and Eric—played key roles in his businesses. Ivanka Trump and her husband, Jared Kushner, became senior White House advisors during the Trump presidency. Trump’s third wife, Melanie Trump (née Knauss), served as First Lady."
tokens = val.split()
for i in range(len(tokens)):
      tokens[i] = tokens[i].lower()
if len(tokens)>3:
    comment_words += " ".join(tokens)+" "

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
words = wordcloud.words_

# %%
for word, frequency in words.items():
    print(f"Word: {word}, Frequency: {frequency:.2f}")
# Out:
# Word: trump, Frequency: 1.00
# Word: president, Frequency: 0.45
# Word: donald, Frequency: 0.23
# Word: s, Frequency: 0.23
# Word: first, Frequency: 0.23
# Word: vote, Frequency: 0.23
# Word: office, Frequency: 0.18
# Word: biden, Frequency: 0.18
# Word: presidency, Frequency: 0.18
# Word: house, Frequency: 0.18
# Word: us, Frequency: 0.18
# Word: victory, Frequency: 0.14
# Word: january, Frequency: 0.14
# Word: years, Frequency: 0.14
# Word: oldest, Frequency: 0.14
# Word: impeached, Frequency: 0.14
# Word: presidential election, Frequency: 0.14
# Word: electoral college, Frequency: 0.14
# Word: inaugurated, Frequency: 0.09
# Word: time, Frequency: 0.09
# Word: supporters, Frequency: 0.09
# Word: person, Frequency: 0.09
# Word: record, Frequency: 0.09
# Word: set, Frequency: 0.09
# Word: ronald, Frequency: 0.09
# Word: reagan, Frequency: 0.09
# Word: took, Frequency: 0.09
# Word: served, Frequency: 0.09
# Word: white, Frequency: 0.09
# Word: second, Frequency: 0.09
# Word: won, Frequency: 0.09
# Word: million, Frequency: 0.09
# Word: twice, Frequency: 0.09
# Word: representatives, Frequency: 0.09
# Word: stood, Frequency: 0.09
# Word: trial, Frequency: 0.09
# Word: senate, Frequency: 0.09
# Word: acquitted, Frequency: 0.09
# Word: led, Frequency: 0.09
# Word: effort, Frequency: 0.09
# Word: born, Frequency: 0.09
# Word: new, Frequency: 0.09
# Word: remained, Frequency: 0.09
# Word: life, Frequency: 0.09
# Word: five, Frequency: 0.09
# Word: children, Frequency: 0.09
# Word: husband, Frequency: 0.09
# Word: real, Frequency: 0.09
# Word: estate, Frequency: 0.09
# Word: business, Frequency: 0.09
# Word: casinos, Frequency: 0.09
# Word: branded, Frequency: 0.09
# Word: products, Frequency: 0.09
# Word: series, Frequency: 0.09
# Word: businesses, Frequency: 0.09
# Word: divorced, Frequency: 0.09
# Word: three, Frequency: 0.09
# Word: ivanka, Frequency: 0.09
# Word: elected, Frequency: 0.05
# Word: november, Frequency: 0.05
# Word: widely, Frequency: 0.05
# Word: seen, Frequency: 0.05
# Word: surprise, Frequency: 0.05
# Word: upset, Frequency: 0.05
# Word: 45th, Frequency: 0.05
# Word: united, Frequency: 0.05
# Word: states, Frequency: 0.05
# Word: left, Frequency: 0.05
# Word: losing, Frequency: 0.05
# Word: former, Frequency: 0.05
# Word: vice, Frequency: 0.05
# Word: joe, Frequency: 0.05
# Word: largely, Frequency: 0.05
# Word: defined, Frequency: 0.05
# Word: scandal, Frequency: 0.05
# Word: investigation, Frequency: 0.05
# Word: intense, Frequency: 0.05
# Word: partisan, Frequency: 0.05
# Word: division, Frequency: 0.05
# Word: critics, Frequency: 0.05
# Word: often, Frequency: 0.05
# Word: used, Frequency: 0.05
# Word: word, Frequency: 0.05
# Word: unprecedented, Frequency: 0.05
# Word: describe, Frequency: 0.05
# Word: number, Frequency: 0.05
# Word: factors, Frequency: 0.05
# Word: marked, Frequency: 0.05
# Word: distinctive, Frequency: 0.05
# Word: even, Frequency: 0.05
# Word: began, Frequency: 0.05
# Word: old, Frequency: 0.05
# Word: become, Frequency: 0.05
# Word: surpassing, Frequency: 0.05
# Word: successor, Frequency: 0.05
# Word: joseph, Frequency: 0.05
# Word: re, Frequency: 0.05
# Word: four, Frequency: 0.05
# Word: later, Frequency: 0.05
# Word: age, Frequency: 0.05
# Word: never, Frequency: 0.05
# Word: either, Frequency: 0.05
# Word: public, Frequency: 0.05
# Word: military, Frequency: 0.05
# Word: leadership, Frequency: 0.05
# Word: arriving, Frequency: 0.05
# Word: finally, Frequency: 0.05
# Word: fifth, Frequency: 0.05
# Word: sixteen, Frequency: 0.05
# Word: win, Frequency: 0.05
# Word: lose, Frequency: 0.05
# Word: popular, Frequency: 0.05
# Word: democratic, Frequency: 0.05
# Word: challenger, Frequency: 0.05
# Word: hillary, Frequency: 0.05
# Word: clinton, Frequency: 0.05
# Word: prevailed, Frequency: 0.05
# Word: december, Frequency: 0.05
# Word: democratically, Frequency: 0.05
# Word: controlled, Frequency: 0.05
# Word: charge, Frequency: 0.05
# Word: abuse, Frequency: 0.05
# Word: power, Frequency: 0.05
# Word: obstruction, Frequency: 0.05
# Word: congress, Frequency: 0.05
# Word: persuade, Frequency: 0.05
# Word: foreign, Frequency: 0.05
# Word: leader, Frequency: 0.05
# Word: volodymyr, Frequency: 0.05
# Word: zelensky, Frequency: 0.05
# Word: ukraine, Frequency: 0.05
# Word: interfere, Frequency: 0.05
# Word: upcoming, Frequency: 0.05
# Word: february, Frequency: 0.05
# Word: stark, Frequency: 0.05
# Word: break, Frequency: 0.05
# Word: past, Frequency: 0.05
# Word: precedent, Frequency: 0.05
# Word: refused, Frequency: 0.05
# Word: concede, Frequency: 0.05
# Word: acknowledge, Frequency: 0.05
# Word: legitimacy, Frequency: 0.05
# Word: approximately, Frequency: 0.05
# Word: protracted, Frequency: 0.05
# Word: undermine, Frequency: 0.05
# Word: certification, Frequency: 0.05
# Word: leading, Frequency: 0.05
# Word: violently, Frequency: 0.05
# Word: assault, Frequency: 0.05
# Word: capitol, Frequency: 0.05
# Word: event, Frequency: 0.05
# Word: impeachment, Frequency: 0.05
# Word: several, Frequency: 0.05
# Word: weeks, Frequency: 0.05
# Word: term, Frequency: 0.05
# Word: expired, Frequency: 0.05
# Word: john, Frequency: 0.05
# Word: borough, Frequency: 0.05
# Word: queens, Frequency: 0.05
# Word: york, Frequency: 0.05
# Word: city, Frequency: 0.05
# Word: june, Frequency: 0.05
# Word: yorker, Frequency: 0.05
# Word: throughout, Frequency: 0.05
# Word: waning, Frequency: 0.05
# Word: months, Frequency: 0.05
# Word: fall, Frequency: 0.05
# Word: formally, Frequency: 0.05
# Word: changed, Frequency: 0.05
# Word: residency, Frequency: 0.05
# Word: florida, Frequency: 0.05
# Word: fourth, Frequency: 0.05
# Word: mary, Frequency: 0.05
# Word: anne, Frequency: 0.05
# Word: macleod, Frequency: 0.05
# Word: fred, Frequency: 0.05
# Word: residential, Frequency: 0.05
# Word: developer, Frequency: 0.05
# Word: young, Frequency: 0.05
# Word: adult, Frequency: 0.05
# Word: father, Frequency: 0.05
# Word: expanded, Frequency: 0.05
# Word: range, Frequency: 0.05
# Word: fields, Frequency: 0.05
# Word: hotels, Frequency: 0.05
# Word: golf, Frequency: 0.05
# Word: courses, Frequency: 0.05
# Word: beauty, Frequency: 0.05
# Word: pageants, Frequency: 0.05
# Word: around, Frequency: 0.05
# Word: world, Frequency: 0.05
# Word: 1970s, Frequency: 0.05
# Word: 1980s, Frequency: 0.05
# Word: cultivated, Frequency: 0.05
# Word: international, Frequency: 0.05
# Word: reputation, Frequency: 0.05
# Word: venues, Frequency: 0.05
# Word: well, Frequency: 0.05
# Word: personally, Frequency: 0.05
# Word: embodiment, Frequency: 0.05

# %%
word_list = list(words.keys())

# %%
print(word_list)
# Out:
# ['trump', 'president', 'donald', 's', 'first', 'vote', 'office', 'biden', 'presidency', 'house', 'us', 'victory', 'january', 'years', 'oldest', 'impeached', 'presidential election', 'electoral college', 'inaugurated', 'time', 'supporters', 'person', 'record', 'set', 'ronald', 'reagan', 'took', 'served', 'white', 'second', 'won', 'million', 'twice', 'representatives', 'stood', 'trial', 'senate', 'acquitted', 'led', 'effort', 'born', 'new', 'remained', 'life', 'five', 'children', 'husband', 'real', 'estate', 'business', 'casinos', 'branded', 'products', 'series', 'businesses', 'divorced', 'three', 'ivanka', 'elected', 'november', 'widely', 'seen', 'surprise', 'upset', '45th', 'united', 'states', 'left', 'losing', 'former', 'vice', 'joe', 'largely', 'defined', 'scandal', 'investigation', 'intense', 'partisan', 'division', 'critics', 'often', 'used', 'word', 'unprecedented', 'describe', 'number', 'factors', 'marked', 'distinctive', 'even', 'began', 'old', 'become', 'surpassing', 'successor', 'joseph', 're', 'four', 'later', 'age', 'never', 'either', 'public', 'military', 'leadership', 'arriving', 'finally', 'fifth', 'sixteen', 'win', 'lose', 'popular', 'democratic', 'challenger', 'hillary', 'clinton', 'prevailed', 'december', 'democratically', 'controlled', 'charge', 'abuse', 'power', 'obstruction', 'congress', 'persuade', 'foreign', 'leader', 'volodymyr', 'zelensky', 'ukraine', 'interfere', 'upcoming', 'february', 'stark', 'break', 'past', 'precedent', 'refused', 'concede', 'acknowledge', 'legitimacy', 'approximately', 'protracted', 'undermine', 'certification', 'leading', 'violently', 'assault', 'capitol', 'event', 'impeachment', 'several', 'weeks', 'term', 'expired', 'john', 'borough', 'queens', 'york', 'city', 'june', 'yorker', 'throughout', 'waning', 'months', 'fall', 'formally', 'changed', 'residency', 'florida', 'fourth', 'mary', 'anne', 'macleod', 'fred', 'residential', 'developer', 'young', 'adult', 'father', 'expanded', 'range', 'fields', 'hotels', 'golf', 'courses', 'beauty', 'pageants', 'around', 'world', '1970s', '1980s', 'cultivated', 'international', 'reputation', 'venues', 'well', 'personally', 'embodiment']

# %%
import random
import nltk
from nltk.corpus import brown

# Load the text corpus
nltk.download('brown')
corpus = brown.words()

# Function to generate random words
def generate_random_words(corpus, num_words):
    random_words = []
    for _ in range(num_words):
        # Choose a random word from the corpus
        random_word = random.choice(corpus)
        random_words.append(random_word)
    return random_words
num_words = 100
random_words = generate_random_words(corpus, num_words)
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.

# %%
print(random_words)
for x in num_words:
# Out:
# ["He's", 'into', 'that', 'hands', 'come', 'Day', 'winders', 'and', 'precise', 'an', 'the', ';', 'she', 'the', 'that', 'would', 'on', 'comparison', 'nuclear', 'that', 'a', 'steering', 'one', 'of', '.', 'to', 'three-inch-wide', 'of', 'all', 'the', 'the', 'than', ',', 'the', 'and', '``', 'unrealistically', ',', 'the', 'soldier', 'bolt', 'Thompson', '.', 'in', 'him', 'is', 'she', 'cropped', '``', 'and', 'amplification', '``', 'incapacitated', 'different', 'honest-to-Betsy', 'the', 'of', 'an', 'out', 'acquisition', 'to', 'to', 'men', 'rise', 'He', 'jacket', 'which', 'had', 'Before', 'After', '.', 'he', '--', 'wider', 'steamship', 'with', 'hit', 'plain', 'the', ',', ',', 'of', 'men', 'off', 'techniques', 'ridden', 'irony', 'Dale', 'suggests', 'cities', 'general', 'time', 'a', 'weeks', 'and', 'found', '.', 'real', 'as', 'characteristic']
